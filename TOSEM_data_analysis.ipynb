# %%
import json
import os
import numpy as np

# %%
"""
When measuring the inference latency of a DNN model, in order to eliminate the impact of environment
noises, instead of recording the prediction latency for each individual testing sample once, we measure the inference
latency of the entire testing dataset for 30 times and take the median value.
"""

# %% [markdown]
# ### MNIST CNN

# %%
mnist_cnn_recorder = dict()

# %%
parent_dir = "TOSEM_data/cnn_image_data/cnn_image_data_server/"
for folder in os.listdir(parent_dir):
    if folder == '.DS_Store':
        continue
    for record in os.listdir(os.path.join(parent_dir, folder)):
        if record.endswith("metrics"):
            target = os.path.join(parent_dir, folder, record)
            with open(target, "r") as ifile:
                temp = ifile.read()
                temp = json.loads(temp)
                mnist_cnn_recorder[folder + "_" + record] = temp

# %%
simlified_cnn_result_list = list()
for key in mnist_cnn_recorder:
    temp = dict()
    temp["hyperparameters"] = mnist_cnn_recorder[key]["hyperparameters"]
    temp["accuracy"] = np.median(mnist_cnn_recorder[key]["original_model"]["accuracy"])
    simlified_cnn_result_list.append(temp)

# %%
sorted(simlified_cnn_result_list, key=lambda x:x["accuracy"], reverse=True)
# Out:
# [{'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 7,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.06350483197533612,
#    'batch_size': 8,
#    'epochs': 44,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9928},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'optimizer': 'SGD',
#    'learning_rate': 0.007360097910140977,
#    'batch_size': 2,
#    'epochs': 86,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9927},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.8179855278075513,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.08004071724388537,
#    'batch_size': 16,
#    'epochs': 79,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9925},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 192,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.867359394670119,
#    'learning_rate': 0.00041316906370540365,
#    'batch_size': 64,
#    'epochs': 81,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9925},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.08004071724388537,
#    'batch_size': 16,
#    'epochs': 79,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9925},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'dropout_ratio': 0.5753358888994525,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0023995130011484015,
#    'batch_size': 64,
#    'epochs': 77,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9918},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.33106740716637534,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.04885562433707262,
#    'batch_size': 32,
#    'epochs': 46,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9918},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0009211820999053567,
#    'batch_size': 2,
#    'epochs': 76,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9918},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.18380213383055324,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00582906468360246,
#    'batch_size': 128,
#    'epochs': 90,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9918},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 24,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.00040276725567357324,
#    'batch_size': 8,
#    'epochs': 67,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9916},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.022117825524369823,
#    'batch_size': 32,
#    'epochs': 68,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9916},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6365109907833152,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0024033422611295947,
#    'epochs': 79,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9916},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 24,
#    'kernel_size': 9,
#    'dropout_ratio': 0.12094555137532367,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.05139450335069961,
#    'batch_size': 1,
#    'epochs': 43,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9915},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0015961522964949126,
#    'batch_size': 64,
#    'epochs': 16,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9915},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 48,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0009540078697370695,
#    'batch_size': 4,
#    'epochs': 88,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9914},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0013468670333022837,
#    'batch_size': 256,
#    'epochs': 17,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9912},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006725159378781032,
#    'batch_size': 512,
#    'epochs': 73,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9911},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6900633118526042,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0022149863476168975,
#    'batch_size': 512,
#    'epochs': 73,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9911},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'dropout_ratio': 0.7831163628664015,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.02832402727438394,
#    'batch_size': 64,
#    'epochs': 75,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.991},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010829283900041387,
#    'batch_size': 8,
#    'epochs': 36,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.991},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 7,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0023520773739202044,
#    'batch_size': 64,
#    'epochs': 36,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9909},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5167736704799243,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0011611123699854526,
#    'batch_size': 256,
#    'epochs': 67,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9908},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 7,
#    'dropout_ratio': 0.36705030063990823,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006007645346425672,
#    'batch_size': 128,
#    'epochs': 73,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9907},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 7,
#    'dropout_ratio': 0.7984830251796051,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0005509826393625321,
#    'batch_size': 128,
#    'epochs': 12,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9907},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 7,
#    'optimizer': 'SGD',
#    'learning_rate': 0.00949583452397775,
#    'batch_size': 4,
#    'epochs': 41,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9907},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.3422347320325506,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.009070318430422733,
#    'epochs': 15,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9907},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 24,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5172535845912225,
#    'learning_rate': 0.0017272611218213392,
#    'batch_size': 16,
#    'epochs': 90,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9906},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 192,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.42734096772994934,
#    'learning_rate': 0.0005749908414035857,
#    'batch_size': 256,
#    'epochs': 83,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9905},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.019778649779272857,
#    'batch_size': 64,
#    'epochs': 66,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9905},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 192,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.493779243729308,
#    'optimizer': 'Nadam',
#    'batch_size': 16,
#    'epochs': 97,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9902},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 48,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.26139736575021105,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.000314359793475872,
#    'epochs': 68,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9902},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.4066702819502005,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0038151575589505686,
#    'batch_size': 16,
#    'epochs': 69,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.7474520529845967,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0002972965302702394,
#    'batch_size': 2,
#    'epochs': 95,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 7,
#    'dropout_ratio': 0.12314529431500126,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.004414573332079325,
#    'batch_size': 1,
#    'epochs': 59,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.045335301715415686,
#    'learning_rate': 0.0021973429654096573,
#    'batch_size': 4,
#    'epochs': 25,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.19828858233992175,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0042001605195528145,
#    'batch_size': 512,
#    'epochs': 72,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 9,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.010346983070108976,
#    'batch_size': 128,
#    'epochs': 94,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.10253798084422003,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.006460546185539812,
#    'batch_size': 2,
#    'epochs': 97,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9901},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.5306572485528067,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.04193208353867027,
#    'batch_size': 4,
#    'epochs': 94,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.99},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 7,
#    'dropout_ratio': 0.013775178075646145,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.06878885333007126,
#    'batch_size': 32,
#    'epochs': 81,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.99},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 7,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0058951061543914786,
#    'batch_size': 128,
#    'epochs': 47,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.99},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 24,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.004882279521514244,
#    'learning_rate': 0.0007844603301288496,
#    'batch_size': 8,
#    'epochs': 54,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9899},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.08239146287787633,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0014850865154910173,
#    'batch_size': 1,
#    'epochs': 35,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9899},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.3431581705411673,
#    'optimizer': 'Adam',
#    'learning_rate': 0.005212802935732381,
#    'batch_size': 512,
#    'epochs': 41,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9897},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 7,
#    'dropout_ratio': 0.23165040521165803,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0005088282356853556,
#    'batch_size': 8,
#    'epochs': 53,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9897},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 48,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0011917765519990475,
#    'batch_size': 32,
#    'epochs': 98,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9897},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 24,
#    'kernel_size': 7,
#    'optimizer': 'SGD',
#    'learning_rate': 0.005868115848558667,
#    'batch_size': 8,
#    'epochs': 59,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9896},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.2556858957227552,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00011287011335464854,
#    'batch_size': 256,
#    'epochs': 72,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9896},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.1315562351678974,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00011752057080609438,
#    'batch_size': 4,
#    'epochs': 53,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.7746373273734098,
#    'learning_rate': 0.004100114993033646,
#    'batch_size': 16,
#    'epochs': 83,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.43725715782183305,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.02510508818003399,
#    'batch_size': 256,
#    'epochs': 65,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.006158026338654233,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0024185070764171095,
#    'batch_size': 128,
#    'epochs': 72,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 192,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0003152414429300929,
#    'batch_size': 16,
#    'epochs': 77,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 5,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0014882518868978467,
#    'batch_size': 4,
#    'epochs': 92,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.5409722635912589,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.000313511186964544,
#    'batch_size': 256,
#    'epochs': 56,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9895},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 48,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.045267748245755246,
#    'learning_rate': 0.00012415922129884135,
#    'batch_size': 4,
#    'epochs': 60,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9894},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 24,
#    'kernel_size': 9,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0016843327340508186,
#    'batch_size': 256,
#    'epochs': 15,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9894},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 9,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00022638581919009622,
#    'batch_size': 2,
#    'epochs': 64,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9894},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'optimizer': 'SGD',
#    'learning_rate': 0.03472774134524792,
#    'batch_size': 128,
#    'epochs': 98,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9893},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 24,
#    'kernel_size': 7,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.013297826728464376,
#    'batch_size': 2,
#    'epochs': 77,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9893},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 192,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.5292650161952281,
#    'optimizer': 'Adam',
#    'batch_size': 64,
#    'epochs': 6,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 96,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.578051152417035,
#    'optimizer': 'Nadam',
#    'batch_size': 256,
#    'epochs': 50,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 5,
#    'dropout_ratio': 0.3980342211852059,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.01445839365084867,
#    'batch_size': 4,
#    'epochs': 67,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.22848619386445246,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00020201817445182854,
#    'batch_size': 8,
#    'epochs': 32,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.3630668249555405,
#    'learning_rate': 0.0017065034591173874,
#    'batch_size': 128,
#    'epochs': 47,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.24620490111352822,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.01220074539121311,
#    'batch_size': 2,
#    'epochs': 70,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.31410354357557996,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.019745186418545946,
#    'batch_size': 32,
#    'epochs': 18,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9892},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.07573538178969991,
#    'optimizer': 'RMSprop',
#    'batch_size': 256,
#    'epochs': 43,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9891},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 24,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00023592509627144774,
#    'batch_size': 4,
#    'epochs': 37,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9891},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.280559829640294,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00042790399423173843,
#    'batch_size': 16,
#    'epochs': 92,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.989},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.17399832887710845,
#    'learning_rate': 0.0035496635322710144,
#    'batch_size': 256,
#    'epochs': 47,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.989},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0006544085784190415,
#    'batch_size': 16,
#    'epochs': 59,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.989},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.3167601229933849,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0779343627553108,
#    'batch_size': 4,
#    'epochs': 83,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.989},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.4083705870521922,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0069843588329759135,
#    'batch_size': 2,
#    'epochs': 33,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9889},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006523389943576092,
#    'batch_size': 256,
#    'epochs': 15,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9889},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'dropout_ratio': 0.1857878367497299,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0004650541653641144,
#    'batch_size': 256,
#    'epochs': 41,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9888},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 24,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0005423152842221075,
#    'batch_size': 32,
#    'epochs': 55,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9888},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 48,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5426419451389087,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0007017067505165284,
#    'epochs': 76,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9888},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.41627039593538334,
#    'optimizer': 'Adam',
#    'learning_rate': 0.002559716200939082,
#    'batch_size': 16,
#    'epochs': 85,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9887},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0006224065081134311,
#    'batch_size': 8,
#    'epochs': 87,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9886},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 9,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.022622454691777986,
#    'batch_size': 512,
#    'epochs': 83,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9886},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.6913485641875647,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.04151449245420631,
#    'batch_size': 128,
#    'epochs': 18,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9885},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 48,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.4490757408924864,
#    'learning_rate': 0.004671621645754273,
#    'batch_size': 512,
#    'epochs': 40,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9885},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 24,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.4402506840045668,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.011606479775475196,
#    'epochs': 65,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9884},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5022698385696956,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.017766096916367366,
#    'batch_size': 64,
#    'epochs': 73,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9883},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 24,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5451591744611989,
#    'optimizer': 'Nadam',
#    'batch_size': 32,
#    'epochs': 26,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9882},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.31932245421584415,
#    'optimizer': 'Adam',
#    'learning_rate': 0.003307813841875074,
#    'batch_size': 16,
#    'epochs': 89,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9881},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'optimizer': 'SGD',
#    'learning_rate': 0.06632609460206541,
#    'batch_size': 8,
#    'epochs': 41,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.988},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 24,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.013174709675129338,
#    'optimizer': 'Nadam',
#    'batch_size': 64,
#    'epochs': 54,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.09355523335849991,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0012623603147565773,
#    'batch_size': 32,
#    'epochs': 36,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 9,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002351698008061067,
#    'batch_size': 64,
#    'epochs': 12,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 192,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.2456793157210584,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.04599146099502252,
#    'epochs': 95,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 48,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.7004127300601632,
#    'optimizer': 'SGD',
#    'learning_rate': 0.05387092388983786,
#    'epochs': 75,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5343046866406498,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.035545092740002865,
#    'batch_size': 8,
#    'epochs': 100,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9879},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 24,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.030835984638883797,
#    'learning_rate': 0.00024961311242408695,
#    'batch_size': 128,
#    'epochs': 80,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9878},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.6739159158960434,
#    'optimizer': 'SGD',
#    'learning_rate': 0.03440003513585681,
#    'batch_size': 8,
#    'epochs': 86,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9878},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 96,
#    'activation': 'relu',
#    'dropout_ratio': 0.41475373605264026,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0044516644860207065,
#    'batch_size': 512,
#    'epochs': 99,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9878},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 96,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.137615107500989,
#    'optimizer': 'RMSprop',
#    'batch_size': 16,
#    'epochs': 51,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9877},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.6423832282387724,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00016438830975200032,
#    'batch_size': 256,
#    'epochs': 52,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9877},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.4602578250123521,
#    'optimizer': 'RMSprop',
#    'batch_size': 256,
#    'epochs': 76,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9876},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.4791190882207784,
#    'optimizer': 'SGD',
#    'learning_rate': 0.00026654919940396224,
#    'batch_size': 4,
#    'epochs': 74,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9876},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.7249257709555369,
#    'optimizer': 'Adam',
#    'learning_rate': 0.011559695091384572,
#    'batch_size': 64,
#    'epochs': 52,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9876},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 24,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0004188561619023862,
#    'batch_size': 512,
#    'epochs': 88,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9876},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.196487752877734,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006227124611750695,
#    'batch_size': 64,
#    'epochs': 37,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9875},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5626557574477092,
#    'optimizer': 'Adam',
#    'learning_rate': 0.006682368701198917,
#    'batch_size': 16,
#    'epochs': 98,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9875},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0026228233420744324,
#    'batch_size': 4,
#    'epochs': 41,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9875},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 24,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5557333864615978,
#    'learning_rate': 0.0003958271671901558,
#    'batch_size': 256,
#    'epochs': 76,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9874},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.29734560035275137,
#    'optimizer': 'Adam',
#    'learning_rate': 0.009233192573218175,
#    'batch_size': 128,
#    'epochs': 35,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9874},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.2838007108823702,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.008283022380578558,
#    'epochs': 63,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9874},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.08371429160117708,
#    'optimizer': 'Adam',
#    'learning_rate': 0.014566938165662593,
#    'batch_size': 128,
#    'epochs': 67,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9873},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 3,
#    'dropout_ratio': 0.6203925891524403,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00191588324321209,
#    'batch_size': 64,
#    'epochs': 65,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9873},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3201034931623452,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.03236561776170139,
#    'batch_size': 2,
#    'epochs': 40,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9873},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.5724493191365649,
#    'optimizer': 'Adamax',
#    'batch_size': 512,
#    'epochs': 35,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9872},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 24,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.2962920807525722,
#    'optimizer': 'Adam',
#    'batch_size': 512,
#    'epochs': 70,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9871},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6377221935013984,
#    'optimizer': 'SGD',
#    'learning_rate': 0.022350431833749955,
#    'batch_size': 16,
#    'epochs': 64,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9871},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 12,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'optimizer': 'SGD',
#    'learning_rate': 0.09596488744265856,
#    'batch_size': 16,
#    'epochs': 37,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9871},
#  {'hyperparameters': {'epochs': 4,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.09356581433032843,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0003117277715131804,
#    'batch_size': 16,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9871},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 24,
#    'kernel_size': 3,
#    'dropout_ratio': 0.2054210977484235,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0876549198256972,
#    'batch_size': 4,
#    'epochs': 70,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 9,
#    'dropout_ratio': 0.18264288924246244,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002725573106727457,
#    'batch_size': 2,
#    'epochs': 89,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 96,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.042289181418638376,
#    'learning_rate': 0.0004633359129586333,
#    'batch_size': 2,
#    'epochs': 6,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.16959077463803363,
#    'learning_rate': 0.0026134560655206246,
#    'batch_size': 1,
#    'epochs': 17,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 12,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.2487553259006715,
#    'learning_rate': 0.006779450100705182,
#    'batch_size': 256,
#    'epochs': 88,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.32410998294017385,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.04320857486823078,
#    'batch_size': 64,
#    'epochs': 50,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 96,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'optimizer': 'Adam',
#    'learning_rate': 0.050592329999897094,
#    'batch_size': 128,
#    'epochs': 81,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 48,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.5787057835889109,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.21495970832419548,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0002706697223192011,
#    'batch_size': 2,
#    'epochs': 91,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.987},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.2816991931501965,
#    'optimizer': 'Adam',
#    'learning_rate': 0.011428571233970827,
#    'batch_size': 16,
#    'epochs': 90,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9869},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.43286847226219655,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9869},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.34454030316413115,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0029530327185104495,
#    'batch_size': 32,
#    'epochs': 68,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9869},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.39346247155909797,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0024471372766385947,
#    'batch_size': 512,
#    'epochs': 85,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9868},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 96,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.2791635206940722,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.016007221138119965,
#    'epochs': 50,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9868},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.18382549087792374,
#    'optimizer': 'SGD',
#    'learning_rate': 0.04036251039565215,
#    'batch_size': 2,
#    'epochs': 10,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9867},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 96,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0001370338647501017,
#    'batch_size': 2,
#    'epochs': 77,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9867},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 192,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0008124548225774734,
#    'batch_size': 2,
#    'epochs': 67,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9867},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.20888547773697194,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.06128573262985331,
#    'batch_size': 2,
#    'epochs': 98,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9866},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.23170778768019754,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.08003918383307998,
#    'batch_size': 8,
#    'epochs': 58,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9866},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 12,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.45691478065343766,
#    'optimizer': 'RMSprop',
#    'batch_size': 512,
#    'epochs': 80,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 6,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.21282632898789222,
#    'optimizer': 'Adamax',
#    'batch_size': 1,
#    'epochs': 29,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.8453499425340723,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.03907952679050509,
#    'batch_size': 256,
#    'epochs': 53,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3859982452163721,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.003647684316808349,
#    'batch_size': 512,
#    'epochs': 87,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 24,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0037241783567077947,
#    'batch_size': 1,
#    'epochs': 21,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 6,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0008204737141899963,
#    'batch_size': 128,
#    'epochs': 26,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 48,
#    'kernel_size': 3,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006007645346425672,
#    'batch_size': 128,
#    'epochs': 73,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 48,
#    'activation': 'relu',
#    'dropout_ratio': 0.45387860686132675,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00011725649613768819,
#    'batch_size': 8,
#    'epochs': 53,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.43641750984617794,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0002146476861134859,
#    'batch_size': 8,
#    'epochs': 91,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9865},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 9,
#    'dropout_ratio': 0.8485388417504034,
#    'optimizer': 'SGD',
#    'learning_rate': 0.028952635155553862,
#    'batch_size': 64,
#    'epochs': 97,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9864},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6048729959691846,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0004535071054086048,
#    'batch_size': 256,
#    'epochs': 64,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9864},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 192,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.3357995969414205,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9864},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.49935905328933866,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.028070966394339487,
#    'epochs': 100,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9864},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 3,
#    'dropout_ratio': 0.49569847952857465,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0010308516297448799,
#    'batch_size': 8,
#    'epochs': 93,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9863},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6195242310850267,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0028745791047186465,
#    'batch_size': 2,
#    'epochs': 45,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9863},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 12,
#    'kernel_size': 5,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00183180989943718,
#    'batch_size': 512,
#    'epochs': 33,
# ...
#    'learning_rate': 0.015267230297095893,
#    'epochs': 26,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9192},
#  {'hyperparameters': {'epochs': 4,
#    'filters': 24,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7163997205971714,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.059684865099642756,
#    'batch_size': 4,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9192},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 12,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.3432956782371079,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.03421328679022995,
#    'batch_size': 4,
#    'epochs': 63,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9191},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 24,
#    'activation': 'relu',
#    'dropout_ratio': 0.5467582032702158,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.0006483530075515636,
#    'batch_size': 2,
#    'epochs': 91,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9191},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.555756084992344,
#    'optimizer': 'Ftrl',
#    'batch_size': 128,
#    'epochs': 42,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9189},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 48,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.006910003869586844,
#    'batch_size': 32,
#    'epochs': 49,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9188},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5146075372477824,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.005220901177397486,
#    'batch_size': 64,
#    'epochs': 93,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9187},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5338165855441318,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00019903853902284322,
#    'batch_size': 128,
#    'epochs': 23,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9182},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.119231278843401,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.0010668367991974368,
#    'batch_size': 8,
#    'epochs': 29,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.918},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7019603401559998,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0046674722992577425,
#    'batch_size': 8,
#    'epochs': 30,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9178},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters': 24,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.6311190939477311,
#    'learning_rate': 0.009700256795291821,
#    'batch_size': 64,
#    'epochs': 68,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9176},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 3,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.03138530540674052,
#    'batch_size': 128,
#    'epochs': 5,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9173},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 12,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.000924808852665345,
#    'batch_size': 1,
#    'epochs': 94,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.917},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.20708428066427767,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0016661737421910957,
#    'batch_size': 64,
#    'epochs': 58,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9169},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.4456608277102268,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00042766928780257825,
#    'batch_size': 256,
#    'epochs': 18,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9168},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7355233941478518,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.00031563360471458104,
#    'batch_size': 1,
#    'epochs': 75,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9168},
#  {'hyperparameters': {'filters': 6,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.06475308075632857,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0011324202299739057,
#    'batch_size': 8,
#    'epochs': 24,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9167},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.36221324898614227,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0004039467124567337,
#    'batch_size': 2,
#    'epochs': 52,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9165},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'filters': 96,
#    'kernel_size': 9,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0007702766337673813,
#    'batch_size': 2,
#    'epochs': 47,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9165},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 6,
#    'activation': 'tanh',
#    'dropout_ratio': 0.4833479244566203,
#    'optimizer': 'Adam',
#    'learning_rate': 0.006605935853123786,
#    'batch_size': 8,
#    'epochs': 13,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9165},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 6,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.7914309663228786,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9163},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.2613001159883856,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9162},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 12,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.8883279889073185,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0006144090320070388,
#    'epochs': 17,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9158},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.8564617596574807,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00161751026837429,
#    'batch_size': 16,
#    'epochs': 59,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9157},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 48,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5415150687126525,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00367827762348497,
#    'batch_size': 1,
#    'epochs': 23,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9155},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.4907589035844866,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0004066189007780814,
#    'batch_size': 128,
#    'epochs': 4,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9153},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7437562671093845,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0007645481459628923,
#    'batch_size': 16,
#    'epochs': 57,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9153},
#  {'hyperparameters': {'epochs': 4,
#    'filters': 192,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.8703721519570247,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0026506711821245167,
#    'batch_size': 2,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9153},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 96,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.40797443953661516,
#    'optimizer': 'SGD',
#    'learning_rate': 0.03329029208362902,
#    'epochs': 91,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9151},
#  {'hyperparameters': {'filters': 48,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.06489117826020166,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.00396551989165945,
#    'batch_size': 2,
#    'epochs': 26,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.915},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 6,
#    'kernel_size': 7,
#    'dropout_ratio': 0.5580890933631649,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0011149169701207952,
#    'batch_size': 512,
#    'epochs': 71,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9149},
#  {'hyperparameters': {'epochs': 4,
#    'filters': 96,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.14922809843523377,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0070784693418159406,
#    'batch_size': 2,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9149},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 48,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3798093542732571,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.017653838257802566,
#    'batch_size': 2,
#    'epochs': 4,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9146},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 24,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.09140271227428064,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9143},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 6,
#    'kernel_size': 5,
#    'dropout_ratio': 0.1871357095562616,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.0022830269875510783,
#    'batch_size': 64,
#    'epochs': 64,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9142},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 96,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.41790381346267397,
#    'optimizer': 'Adagrad',
#    'batch_size': 1,
#    'epochs': 72,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9139},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.49569607175977176,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0001343627109658981,
#    'batch_size': 2,
#    'epochs': 12,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9139},
#  {'hyperparameters': {'filters': 24,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.2784828328081646,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.011091497263757967,
#    'batch_size': 32,
#    'epochs': 63,
#    'pool_type': 'max',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9139},
#  {'hyperparameters': {'filters': 6,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.7645931468430431,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.024625231843220092,
#    'batch_size': 32,
#    'epochs': 11,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9138},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters': 6,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5531617944064229,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.002058227972753007,
#    'batch_size': 8,
#    'epochs': 79,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9138},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 6,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7687053806191104,
#    'optimizer': 'Ftrl',
#    'batch_size': 1,
#    'epochs': 80,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9137},
#  {'hyperparameters': {'filters': 96,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.6061435826901965,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0017800442201034632,
#    'batch_size': 8,
#    'epochs': 75,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9134},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters': 48,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7104740548840114,
#    'optimizer': 'SGD',
#    'batch_size': 64,
#    'epochs': 31,
#    'pool_type': 'avg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.9132},
#  {'hyperparameters': {'batch_size': 128,
#    'filters': 96,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.1521460530865405,
#    'optimizer': 'SGD',
#    'learning_rate': 0.020844154682866385,
#    'epochs': 19,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9132},
#  {'hyperparameters': {'epochs': 4,
#    'filters': 48,
#    'kernel_size': 5,
#    'activation': 'tanh',
#    'dropout_ratio': 0.4446826363255812,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.000716100777555975,
#    'batch_size': 1,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9131},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 192,
#    'kernel_size': 3,
#    'activation': 'tanh',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0293409216347527,
#    'batch_size': 512,
#    'epochs': 82,
#    'pool_type': 'avg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.913},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 128,
#    'epochs': 4,
#    'filters': 192,
#    'kernel_size': 5,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5313598533290356,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.913},
#  {'hyperparameters': {'filters': 192,
#    'kernel_size': 7,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.05520379821033047,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.019464029077006405,
#    'batch_size': 512,
#    'epochs': 51,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.913},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'filters': 192,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'optimizer': 'SGD',
#    'learning_rate': 0.001391675565576476,
#    'batch_size': 64,
#    'epochs': 11,
#    'pool_type': 'max',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9127},
#  {'hyperparameters': {'filters': 12,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.5593724693051603,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0006158479073904083,
#    'batch_size': 32,
#    'epochs': 84,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9127},
#  {'hyperparameters': {'activation': 'relu',
#    'filters': 192,
#    'kernel_size': 3,
#    'dropout_ratio': 0.6882945090683218,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.014874924544586608,
#    'batch_size': 512,
#    'epochs': 79,
#    'pool_type': 'max',
#    'loss_function': 'poisson'},
#   'accuracy': 0.9123},
#  ...]

# %% [markdown]
# ### Resnet

# %%
resnet_cnn_recorder = dict()

# %%
parent_dir = "TOSEM_data/resnet_data/resnet_data_server/"
for folder in os.listdir(parent_dir):
    if folder == '.DS_Store':
        continue
    for record in os.listdir(os.path.join(parent_dir, folder)):
        if record.endswith("metrics"):
            target = os.path.join(parent_dir, folder, record)
            with open(target, "r") as ifile:
                temp = ifile.read()
                temp = json.loads(temp)
                resnet_cnn_recorder[folder + "_" + record] = temp

# %%
simlified_resnet_result_list = list()
for key in resnet_cnn_recorder:
    temp = dict()
    temp["hyperparameters"] = resnet_cnn_recorder[key]["hyperparameters"]
    temp["accuracy"] = np.median(resnet_cnn_recorder[key]["original_model"]["accuracy"])
    simlified_resnet_result_list.append(temp)

# %%
sorted(simlified_resnet_result_list, key=lambda x:x["accuracy"], reverse=True)
# Out:
# [{'hyperparameters': {'filters': 192,
#    'kernel_size': 3,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6940142047640246,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0007035352823091709,
#    'batch_size': 256,
#    'epochs': 56,
#    'pool_type': 'avg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.9384},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 64,
#    'dropout_ratio': 0.19012400969749255,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006515972222658095,
#    'batch_size': 16,
#    'epochs': 84,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7837},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 64,
#    'activation': 'relu',
#    'dropout_ratio': 0.37835993947077656,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 53,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.775},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 32,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.389604494237853,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.034202321573039145,
#    'batch_size': 64,
#    'epochs': 42,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.771},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 64,
#    'filters_4': 128,
#    'filters_5': 256,
#    'dropout_ratio': 0.32977164760212657,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.003270894869029187,
#    'batch_size': 64,
#    'epochs': 67,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7703},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 64,
#    'filters_5': 16,
#    'activation': 'relu',
#    'dropout_ratio': 0.12286234132778098,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 46,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7668},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.7069253922383375,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'learning_rate': 0.019195873911939804,
#    'batch_size': 64,
#    'epochs': 66,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7563},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 256,
#    'filters_4': 128,
#    'filters_5': 32,
#    'dropout_ratio': 0.43741237444038367,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.004380864690670071,
#    'batch_size': 32,
#    'epochs': 25,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7548},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.08278089223723574,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.006751635024208571,
#    'batch_size': 64,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7517},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 16,
#    'filters_5': 1024,
#    'activation': 'relu',
#    'dropout_ratio': 0.04430080101365546,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0014645090131287844,
#    'batch_size': 32,
#    'epochs': 76,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7513},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 512,
#    'filters_5': 64,
#    'activation': 'relu',
#    'dropout_ratio': 0.18436671414009514,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.012324721550013002,
#    'epochs': 99,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7509},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 16,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.19528603482292403,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.006719715882357453,
#    'batch_size': 128,
#    'epochs': 88,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7505},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 64,
#    'filters_5': 1024,
#    'activation': 'relu',
#    'dropout_ratio': 0.046297424064047125,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.75},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 256,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.4241485144516799,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.011781455875415684,
#    'batch_size': 32,
#    'epochs': 99,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7475},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 16,
#    'filters_5': 1024,
#    'activation': 'tanh',
#    'dropout_ratio': 0.4198036502852021,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0005877925871688004,
#    'batch_size': 16,
#    'epochs': 53,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7462},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 512,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.41546198292815945,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7459},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 64,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.07211423641810104,
#    'batch_size': 32,
#    'epochs': 46,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7457},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7227664257848377,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0002649259416228259,
#    'batch_size': 16,
#    'epochs': 96,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7456},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 16,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.5420186783228347,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002294212165388416,
#    'batch_size': 64,
#    'epochs': 75,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7456},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.2617622789502776,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.03007711335933778,
#    'batch_size': 256,
#    'epochs': 91,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7453},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.767045023096847,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.001216924731750547,
#    'batch_size': 32,
#    'epochs': 50,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.745},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 64,
#    'filters_4': 128,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.4535327152673689,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'learning_rate': 0.0013476500398946433,
#    'batch_size': 64,
#    'epochs': 44,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7447},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.42980294909365696,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.022158070582774983,
#    'batch_size': 128,
#    'epochs': 79,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7441},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 64,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.4439437727640784,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0012567208642033445,
#    'epochs': 48,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7438},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 32,
#    'filters_5': 256,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0004969182256225593,
#    'batch_size': 32,
#    'epochs': 53,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7434},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 32,
#    'filters_4': 512,
#    'filters_5': 16,
#    'activation': 'relu',
#    'dropout_ratio': 0.7974660221695229,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.01020104005331319,
#    'batch_size': 32,
#    'epochs': 89,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7432},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 512,
#    'filters_5': 256,
#    'dropout_ratio': 0.3021378008399827,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.08932618889764558,
#    'batch_size': 64,
#    'epochs': 32,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7432},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 64,
#    'filters_5': 1024,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.7002407203134117,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006592477718847648,
#    'epochs': 28,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7424},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5695765105470926,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'learning_rate': 0.011724702127950806,
#    'batch_size': 16,
#    'epochs': 50,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7422},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 16,
#    'activation': 'relu',
#    'dropout_ratio': 0.7630616585441224,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.005417973874666322,
#    'batch_size': 64,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7422},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 16,
#    'filters_5': 1024,
#    'dropout_ratio': 0.15291702262590715,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0008988324897020811,
#    'batch_size': 32,
#    'epochs': 79,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7418},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 16,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5614336707702414,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006837154378198909,
#    'batch_size': 32,
#    'epochs': 76,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7416},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.35879508667282356,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00029774317743562614,
#    'batch_size': 16,
#    'epochs': 63,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7413},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 16,
#    'filters_5': 128,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.041960560519906896,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.06517933150732032,
#    'batch_size': 64,
#    'epochs': 24,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7403},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 512,
#    'filters_5': 1024,
#    'activation': 'relu',
#    'dropout_ratio': 0.06946668795357976,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7389},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 16,
#    'filters_5': 1024,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.18483833879739042,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.001303285379513526,
#    'batch_size': 16,
#    'epochs': 60,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7388},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 64,
#    'filters_4': 512,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.8139830156418697,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.011965744369339311,
#    'batch_size': 64,
#    'epochs': 84,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7388},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 16,
#    'filters_5': 32,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002182877212673191,
#    'batch_size': 16,
#    'epochs': 46,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7387},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 16,
#    'filters_3': 32,
#    'filters_4': 256,
#    'filters_5': 256,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.15409637065171106,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.001124001656101176,
#    'batch_size': 16,
#    'epochs': 88,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7386},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.10618226237832594,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.02661877777328162,
#    'batch_size': 64,
#    'epochs': 20,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7386},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3278964167854362,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0010165435820843763,
#    'epochs': 49,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.738},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 512,
#    'filters_5': 128,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00014367632995710257,
#    'batch_size': 16,
#    'epochs': 51,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.738},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 16,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 64,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.23010426554793081,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.738},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5831452010402791,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0004619667864757889,
#    'epochs': 28,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7375},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 64,
#    'filters_5': 32,
#    'optimizer': 'Adam',
#    'learning_rate': 0.03035953597313,
#    'batch_size': 64,
#    'epochs': 49,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7375},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 7,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3180648988306516,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'learning_rate': 0.05303111317339599,
#    'batch_size': 32,
#    'epochs': 45,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7369},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 512,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.2909409765447939,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'batch_size': 64,
#    'epochs': 65,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7359},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.797895262308304,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0006714803945207539,
#    'batch_size': 16,
#    'epochs': 85,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7356},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 16,
#    'filters_5': 256,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.13224788988775796,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.051425181114716945,
#    'epochs': 88,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7355},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 16,
#    'filters_5': 256,
#    'activation': 'relu',
#    'dropout_ratio': 0.023176174672831753,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7353},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 9,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.34663479707731243,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0005899711794290387,
#    'batch_size': 64,
#    'epochs': 73,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7352},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 3,
#    'filters_1': 16,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.3775479165760817,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'learning_rate': 0.0022544123485863585,
#    'batch_size': 32,
#    'epochs': 32,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7351},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6355440535422375,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.010365570288189395,
#    'batch_size': 16,
#    'epochs': 77,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7347},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 128,
#    'filters_4': 512,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.13812317864868484,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.012595507442722755,
#    'batch_size': 64,
#    'epochs': 34,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7344},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 16,
#    'optimizer': 'Adam',
#    'learning_rate': 0.011381100243461124,
#    'batch_size': 128,
#    'epochs': 100,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7335},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 128,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.2671085104209668,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.008489049578900502,
#    'batch_size': 16,
#    'epochs': 41,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7335},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 128,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5126994791537771,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.0013096033604495054,
#    'batch_size': 32,
#    'epochs': 25,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7333},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 64,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.14885922280036584,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0011696078999495947,
#    'batch_size': 64,
#    'epochs': 84,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7328},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 32,
#    'filters_4': 128,
#    'filters_5': 64,
#    'activation': 'relu',
#    'dropout_ratio': 0.135931050167225,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'learning_rate': 0.004877795137126273,
#    'batch_size': 128,
#    'epochs': 69,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7326},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 16,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5315610894501638,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'learning_rate': 0.002795460351385751,
#    'batch_size': 64,
#    'epochs': 79,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7326},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 16,
#    'activation': 'tanh',
#    'dropout_ratio': 0.21518887690102576,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7324},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 16,
#    'filters_4': 256,
#    'filters_5': 16,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0012983366147820373,
#    'batch_size': 128,
#    'epochs': 88,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7322},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 16,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 32,
#    'filters_5': 256,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.005978706236565939,
#    'batch_size': 64,
#    'epochs': 71,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7314},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 64,
#    'filters_5': 64,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.008994169021760937,
#    'batch_size': 512,
#    'epochs': 39,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7308},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 16,
#    'filters_4': 512,
#    'filters_5': 256,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0003883366580587091,
#    'batch_size': 32,
#    'epochs': 58,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7307},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 256,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.6495540513898941,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00016131159046297355,
#    'epochs': 74,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7304},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 512,
#    'filters_5': 16,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0021973429654096573,
#    'batch_size': 512,
#    'epochs': 25,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7299},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.7476037052072919,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.003049914764363348,
#    'batch_size': 64,
#    'epochs': 63,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7297},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.38320789800587146,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.019123544600209857,
#    'batch_size': 16,
#    'epochs': 79,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7295},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 256,
#    'filters_5': 1024,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00031766753460348214,
#    'batch_size': 128,
#    'epochs': 79,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7292},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 16,
#    'filters_5': 32,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.001511192621920464,
#    'batch_size': 64,
#    'epochs': 20,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7278},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7402421254350117,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0005588613350782036,
#    'batch_size': 32,
#    'epochs': 96,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7273},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.010292914465806513,
#    'batch_size': 16,
#    'epochs': 77,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7272},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 16,
#    'filters_3': 256,
#    'filters_4': 16,
#    'filters_5': 64,
#    'activation': 'relu',
#    'dropout_ratio': 0.1195090969095977,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.727},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 16,
#    'filters_4': 512,
#    'filters_5': 128,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.005815000286373891,
#    'batch_size': 64,
#    'epochs': 28,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7268},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 64,
#    'filters_5': 64,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0059315841751772826,
#    'batch_size': 256,
#    'epochs': 58,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7262},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 64,
#    'filters_4': 512,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.6423832282387724,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0035154209941911235,
#    'batch_size': 32,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7261},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 128,
#    'filters_4': 32,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.19672658163734322,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7258},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.7328446559367348,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0049877393297526815,
#    'batch_size': 16,
#    'epochs': 72,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7255},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.74287688067532,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7252},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 512,
#    'filters_5': 16,
#    'activation': 'relu',
#    'dropout_ratio': 0.6593496226318488,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.014091672487625048,
#    'batch_size': 128,
#    'epochs': 36,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7252},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 9,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3383798292713209,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.004571707216730056,
#    'batch_size': 128,
#    'epochs': 58,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.725},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 32,
#    'filters_4': 256,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7617570347007717,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.004991244511033044,
#    'batch_size': 64,
#    'epochs': 47,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7248},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 256,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5763742984768084,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006556045636980256,
#    'batch_size': 256,
#    'epochs': 64,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7247},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 256,
#    'filters_4': 128,
#    'filters_5': 16,
#    'activation': 'tanh',
#    'dropout_ratio': 0.29999770792932856,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7247},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 64,
#    'filters_3': 64,
#    'filters_4': 256,
#    'filters_5': 64,
#    'activation': 'relu',
#    'dropout_ratio': 0.19834676090754014,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'batch_size': 16,
#    'epochs': 79,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7243},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 64,
#    'filters_4': 16,
#    'filters_5': 256,
#    'activation': 'sigmoid',
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.002230951795500235,
#    'batch_size': 32,
#    'epochs': 100,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7242},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6161892369373689,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002493105400960165,
#    'batch_size': 512,
#    'epochs': 57,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7241},
#  {'hyperparameters': {'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 16,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.3957303377311871,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.007699234799033677,
#    'batch_size': 256,
#    'epochs': 71,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7238},
#  {'hyperparameters': {'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 32,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.5814706058011385,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00019262099478743646,
#    'batch_size': 16,
#    'epochs': 68,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7238},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 64,
#    'filters_3': 256,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.3410077921550949,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'batch_size': 256,
#    'epochs': 100,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7235},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 128,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5008402986164724,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.00042689879363973297,
#    'batch_size': 256,
#    'epochs': 86,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7234},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 128,
#    'filters_5': 128,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00021134867621410797,
#    'batch_size': 64,
#    'epochs': 72,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7234},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 64,
#    'filters_3': 256,
#    'filters_4': 256,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.7835202878754103,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.010789517998426394,
#    'batch_size': 16,
#    'epochs': 58,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7234},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.1532008906099964,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0025392780541256084,
#    'batch_size': 16,
#    'epochs': 59,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.723},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 32,
#    'filters_4': 32,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5192390316348745,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.003443442513871206,
#    'batch_size': 512,
#    'epochs': 77,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7228},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 16,
#    'filters_4': 128,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5915670080254571,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.0005713804599034108,
#    'batch_size': 32,
#    'epochs': 92,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7226},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 32,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.8305514486457465,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.01527866196841687,
#    'batch_size': 64,
#    'epochs': 65,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7226},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.710659898482251,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'learning_rate': 0.0015108431109489206,
#    'batch_size': 64,
#    'epochs': 52,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7224},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 16,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.09620852653815117,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7211},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 16,
#    'filters_3': 32,
#    'filters_4': 32,
#    'filters_5': 1024,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.0926052867786407,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0001981176697277812,
#    'batch_size': 16,
#    'epochs': 59,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.721},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.01,
#    'batch_size': 32,
#    'epochs': 25,
#    'kernel_size': 9,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.16588267936290163,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7209},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 64,
#    'filters_3': 64,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.537160180405006,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0021554039443175844,
#    'batch_size': 512,
#    'epochs': 91,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.7208},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 16,
#    'filters_3': 64,
#    'filters_4': 256,
#    'filters_5': 16,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5664725439485055,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.049385011643424084,
#    'epochs': 57,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7204},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 5,
#    'activation': 'relu',
#    'dropout_ratio': 0.32460564415755394,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00032509329096771275,
#    'batch_size': 128,
#    'epochs': 58,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7202},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 128,
#    'filters_5': 512,
#    'optimizer': 'Adam',
#    'learning_rate': 0.03014307520134737,
#    'batch_size': 64,
#    'epochs': 30,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7201},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 64,
#    'filters_3': 16,
#    'filters_4': 128,
#    'filters_5': 128,
#    'dropout_ratio': 0.8456100732378546,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0005665392164751327,
#    'batch_size': 32,
#    'epochs': 97,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.72},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.3124163014402655,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.064763735696253,
#    'batch_size': 32,
#    'epochs': 35,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7199},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 16,
#    'optimizer': 'Adam',
#    'learning_rate': 0.015182827534844229,
#    'batch_size': 512,
#    'epochs': 35,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7199},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'dropout_ratio': 0.387136686142956,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00019096397690327913,
#    'batch_size': 32,
#    'epochs': 37,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7197},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 64,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.004281479556942885,
#    'batch_size': 16,
#    'epochs': 52,
#    'loss_function': 'poisson'},
#   'accuracy': 0.7195},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 5,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 64,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.8447424251156773,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.004113806564680216,
#    'batch_size': 32,
#    'epochs': 84,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.7192},
# ...
#    'optimizer': 'Adam',
#    'learning_rate': 0.007282664641519587,
#    'batch_size': 128,
#    'epochs': 39,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4724},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 32,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.5768708140585962,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.012222997633236386,
#    'batch_size': 32,
#    'epochs': 22,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4722},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.19278822175644322,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'batch_size': 512,
#    'epochs': 46,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4719},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 16,
#    'filters_3': 64,
#    'filters_4': 512,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.6859170100959482,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00792165881688773,
#    'batch_size': 512,
#    'epochs': 76,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4712},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 64,
#    'filters_4': 32,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.47215422003090946,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.012999633659360675,
#    'epochs': 66,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.47},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 64,
#    'filters_5': 1024,
#    'activation': 'relu',
#    'dropout_ratio': 0.5400435977041858,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0006054260663716899,
#    'batch_size': 512,
#    'epochs': 19,
#    'loss_function': 'poisson'},
#   'accuracy': 0.47},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7142946514541897,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.02073251666381204,
#    'batch_size': 16,
#    'epochs': 71,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4687},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 9,
#    'activation': 'relu',
#    'dropout_ratio': 0.697694668958261,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.00011995825549951965,
#    'batch_size': 512,
#    'epochs': 39,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4684},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 9,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 16,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.006518451089108992,
#    'batch_size': 32,
#    'epochs': 8,
#    'loss_function': 'poisson'},
#   'accuracy': 0.467},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 16,
#    'filters_3': 16,
#    'filters_4': 32,
#    'filters_5': 1024,
#    'activation': 'tanh',
#    'dropout_ratio': 0.30884215162580125,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'learning_rate': 0.00016618811862318417,
#    'batch_size': 32,
#    'epochs': 55,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4668},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 16,
#    'filters_3': 16,
#    'filters_4': 64,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.7438892345748613,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0001954648298845886,
#    'batch_size': 256,
#    'epochs': 20,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4663},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'filters_3': 32,
#    'filters_4': 128,
#    'filters_5': 128,
#    'dropout_ratio': 0.4686879536756583,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'learning_rate': 0.000461615556591795,
#    'batch_size': 256,
#    'epochs': 94,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4662},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.15245623861908678,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.031914687806137106,
#    'batch_size': 512,
#    'epochs': 67,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.466},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.5477510658142275,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.009845579207932633,
#    'batch_size': 256,
#    'epochs': 64,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4659},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 9,
#    'filters_1': 64,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 16,
#    'filters_5': 256,
#    'optimizer': 'SGD',
#    'learning_rate': 0.001155178960027885,
#    'batch_size': 16,
#    'epochs': 25,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4641},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 16,
#    'filters_3': 16,
#    'filters_4': 16,
#    'filters_5': 512,
#    'activation': 'tanh',
#    'dropout_ratio': 0.6168508894076485,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adadelta',
#    'batch_size': 32,
#    'epochs': 83,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4635},
#  {'hyperparameters': {'activation': 'relu',
#    'kernel_size': 5,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 32,
#    'filters_5': 64,
#    'dropout_ratio': 0.028123490046792234,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0006898458472429359,
#    'batch_size': 128,
#    'epochs': 96,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4634},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 16,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 32,
#    'activation': 'tanh',
#    'dropout_ratio': 0.8850685461866037,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0009322603482929008,
#    'batch_size': 512,
#    'epochs': 66,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4631},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 7,
#    'activation': 'relu',
#    'dropout_ratio': 0.6249582091845997,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.002753806546795929,
#    'batch_size': 16,
#    'epochs': 36,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.462},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 16,
#    'activation': 'relu',
#    'dropout_ratio': 0.0864462915679069,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'batch_size': 32,
#    'epochs': 92,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4617},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 32,
#    'filters_4': 16,
#    'filters_5': 64,
#    'activation': 'tanh',
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.010248357715680665,
#    'batch_size': 256,
#    'epochs': 81,
#    'loss_function': 'poisson'},
#   'accuracy': 0.461},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 256,
#    'filters_5': 16,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.3798096149931127,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00021946955800391602,
#    'batch_size': 256,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4607},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 16,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 128,
#    'activation': 'tanh',
#    'dropout_ratio': 0.6523083773949413,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0002052241509931913,
#    'batch_size': 64,
#    'epochs': 84,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4598},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'dropout_ratio': 0.6811641845335663,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.049758082624983775,
#    'batch_size': 16,
#    'epochs': 44,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4596},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 5,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 16,
#    'filters_5': 16,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0011954801238524611,
#    'batch_size': 32,
#    'epochs': 94,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4592},
#  {'hyperparameters': {'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 256,
#    'filters_4': 512,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.7402269636787738,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adam',
#    'learning_rate': 0.004419772860765412,
#    'batch_size': 32,
#    'epochs': 39,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4584},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 9,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 128,
#    'filters_4': 128,
#    'filters_5': 128,
#    'activation': 'relu',
#    'dropout_ratio': 0.3381296437125851,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'SGD',
#    'batch_size': 128,
#    'epochs': 77,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4578},
#  {'hyperparameters': {'kernel_size': 7,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 512,
#    'filters_5': 512,
#    'activation': 'relu',
#    'dropout_ratio': 0.09326594220367138,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adam',
#    'learning_rate': 0.00010712623381634753,
#    'batch_size': 256,
#    'epochs': 33,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4574},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 16,
#    'filters_4': 32,
#    'filters_5': 16,
#    'activation': 'relu',
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0005795398295497946,
#    'batch_size': 512,
#    'epochs': 25,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4565},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 128,
#    'filters_3': 64,
#    'filters_4': 256,
#    'filters_5': 1024,
#    'activation': 'relu',
#    'dropout_ratio': 0.2551848492155273,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0009765550877064469,
#    'batch_size': 256,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4563},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 128,
#    'filters_3': 16,
#    'filters_4': 16,
#    'filters_5': 256,
#    'activation': 'relu',
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'SGD',
#    'learning_rate': 0.0017022080903485272,
#    'batch_size': 512,
#    'epochs': 52,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4562},
#  {'hyperparameters': {'epochs': 25,
#    'kernel_size': 7,
#    'filters_1': 128,
#    'filters_2': 16,
#    'filters_3': 16,
#    'filters_4': 128,
#    'filters_5': 1024,
#    'activation': 'tanh',
#    'dropout_ratio': 0.3205632874433871,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.01266819606925135,
#    'batch_size': 128,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4552},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 7,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 512,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'pooling_1': 'avg',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.010313050200473428,
#    'batch_size': 512,
#    'epochs': 11,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4547},
#  {'hyperparameters': {'learning_rate': 0.01,
#    'kernel_size': 9,
#    'filters_1': 64,
#    'filters_2': 32,
#    'filters_3': 32,
#    'filters_4': 256,
#    'filters_5': 32,
#    'activation': 'relu',
#    'dropout_ratio': 0.6075249217551973,
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'batch_size': 32,
#    'epochs': 25,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4546},
#  {'hyperparameters': {'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'kernel_size': 3,
#    'filters_1': 32,
#    'filters_2': 32,
#    'filters_3': 256,
#    'filters_4': 32,
#    'filters_5': 256,
#    'activation': 'tanh',
#    'dropout_ratio': 0.061953378302257014,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0003563590908864417,
#    'batch_size': 32,
#    'epochs': 15,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4545},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'kernel_size': 3,
#    'activation': 'relu',
#    'dropout_ratio': 0.8039044782376378,
#    'pooling_1': 'max',
#    'pooling_2': 'globalmax',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0012229274565362207,
#    'batch_size': 16,
#    'epochs': 67,
#    'loss_function': 'poisson'},
#   'accuracy': 0.4538},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'kernel_size': 7,
#    'filters_1': 16,
#    'filters_2': 32,
#    'filters_3': 128,
#    'filters_4': 256,
#    'filters_5': 512,
#    'activation': 'sigmoid',
#    'pooling_1': 'avg',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.00021771085878134665,
#    'batch_size': 32,
#    'epochs': 16,
#    'loss_function': 'categorical_crossentropy'},
#   'accuracy': 0.4537},
#  {'hyperparameters': {'batch_size': 32,
#    'kernel_size': 3,
#    'filters_1': 128,
#    'filters_2': 32,
#    'filters_3': 16,
#    'filters_4': 32,
#    'filters_5': 1024,
#    'activation': 'tanh',
#    'dropout_ratio': 0.020215873193662515,
#    'pooling_1': 'max',
#    'pooling_2': 'globalavg',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0001147109968402579,
#    'epochs': 48,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.4529},
#  ...]

# %% [markdown]
# ### CNN for Text

# %%
text_cnn_recorder = dict()

# %%
parent_dir = "TOSEM_data/cnn_text_data/cnn_text_data_server/"
for folder in os.listdir(parent_dir):
    if folder == '.DS_Store':
        continue
    for record in os.listdir(os.path.join(parent_dir, folder)):
        if record.endswith("metrics"):
            target = os.path.join(parent_dir, folder, record)
            with open(target, "r") as ifile:
                temp = ifile.read()
                temp = json.loads(temp)
                text_cnn_recorder[folder + "_" + record] = temp

# %%
simlified_textcnn_result_list = list()
for key in text_cnn_recorder:
    temp = dict()
    temp["hyperparameters"] = text_cnn_recorder[key]["hyperparameters"]
    temp["accuracy"] = np.median(text_cnn_recorder[key]["original_model"]["accuracy"])
    simlified_textcnn_result_list.append(temp)

# %%
sorted(simlified_textcnn_result_list, key=lambda x:x["accuracy"], reverse=True)
# Out:
# [{'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 128,
#    'filters_2': 32,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 32,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.8308531722197221,
#    'dropout_ratio_2': 0.6989564855665645,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8894},
#  {'hyperparameters': {'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 256,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0017166091177458257,
#    'batch_size': 32,
#    'epochs': 92,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88432},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 32,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 16,
#    'dropout_ratio_1': 0.7297340697252819,
#    'dropout_ratio_2': 0.4704462247490652,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0019586936025796976,
#    'batch_size': 64,
#    'epochs': 14,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88352},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 128,
#    'filters_2': 8,
#    'kernel_size_1': 9,
#    'kernel_size_2': 5,
#    'neurons': 32,
#    'embedding_dim': 128,
#    'dropout_ratio_1': 0.08920118842131879,
#    'dropout_ratio_2': 0.7170009632237734,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00017374640767195277,
#    'batch_size': 16,
#    'epochs': 99,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88284},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.07321932139341185,
#    'dropout_ratio_2': 0.14922423108367938,
#    'optimizer': 'Nadam',
#    'batch_size': 32,
#    'epochs': 24,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8818},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 8,
#    'embedding_dim': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.058874667432582704,
#    'dropout_ratio_2': 0.11856094833881971,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88052},
#  {'hyperparameters': {'filters_1': 256,
#    'filters_2': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 5,
#    'neurons': 128,
#    'embedding_dim': 64,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.80312139574844,
#    'dropout_ratio_2': 0.709365230083404,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0804925654160973,
#    'batch_size': 16,
#    'epochs': 91,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87932},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 32,
#    'embedding_dim': 128,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.024803136565977147,
#    'dropout_ratio_2': 0.6274181123843869,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0007677746436373587,
#    'batch_size': 64,
#    'epochs': 36,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87928},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 64,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 128,
#    'dropout_ratio_1': 0.04806982053989839,
#    'dropout_ratio_2': 0.06698300281554297,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00019760820924903568,
#    'batch_size': 256,
#    'epochs': 12,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87912},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 8,
#    'filters_2': 8,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 16,
#    'embedding_dim': 32,
#    'dropout_ratio_1': 0.18114925415214064,
#    'dropout_ratio_2': 0.07573538178969991,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0044799520694057396,
#    'batch_size': 128,
#    'epochs': 70,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8788},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.3437080827810845,
#    'dropout_ratio_2': 0.3500679597356012,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00020825363809644841,
#    'batch_size': 64,
#    'epochs': 94,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87848},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 256,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.8679671825443377,
#    'dropout_ratio_2': 0.32563510158945785,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87824},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 32,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 256,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.4353812823633234,
#    'dropout_ratio_2': 0.7889387228829566,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87784},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 7,
#    'embedding_dim': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.29641333884107773,
#    'dropout_ratio_2': 0.14341667668739932,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00021204361230613814,
#    'batch_size': 32,
#    'epochs': 75,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87784},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 64,
#    'filters_2': 32,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 256,
#    'embedding_dim': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7544780052171449,
#    'dropout_ratio_2': 0.47418342960712323,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87708},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 16,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 16,
#    'embedding_dim': 256,
#    'dropout_ratio_1': 0.21368121796495979,
#    'dropout_ratio_2': 0.7265529966800466,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00048231759024300954,
#    'batch_size': 32,
#    'epochs': 80,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87688},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 32,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 32,
#    'embedding_dim': 16,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.361057226824416,
#    'dropout_ratio_2': 0.877969229788234,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87604},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 32,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 32,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.36747498010730495,
#    'dropout_ratio_2': 0.4907589035844866,
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 65,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87584},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters_1': 128,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 8,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5752043783735257,
#    'dropout_ratio_2': 0.15232485954804265,
#    'learning_rate': 0.0002287116119750084,
#    'batch_size': 32,
#    'epochs': 5,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87556},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 32,
#    'kernel_size_1': 3,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.7283576576933455,
#    'dropout_ratio_2': 0.09995272568205209,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8754},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'embedding_dim': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7583013312463588,
#    'dropout_ratio_2': 0.3326588736770595,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87528},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 128,
#    'filters_2': 64,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'embedding_dim': 256,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6046779602705108,
#    'dropout_ratio_2': 0.0049566681544088945,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87528},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.8856785009090921,
#    'dropout_ratio_2': 0.5696448400672697,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87496},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters_1': 16,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 256,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.847727229776179,
#    'dropout_ratio_2': 0.4669744753420004,
#    'learning_rate': 0.005833888388295045,
#    'batch_size': 512,
#    'epochs': 67,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87476},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 128,
#    'filters_2': 16,
#    'kernel_size_1': 7,
#    'kernel_size_2': 9,
#    'neurons': 32,
#    'embedding_dim': 16,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0022287787644442304,
#    'batch_size': 64,
#    'epochs': 14,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87444},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'embedding_dim': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.8791318717680334,
#    'dropout_ratio_2': 0.527670507862628,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0013452388723909424,
#    'batch_size': 32,
#    'epochs': 25,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87408},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 128,
#    'filters_2': 32,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.38467730309547954,
#    'dropout_ratio_2': 0.10049778338918842,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87404},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 32,
#    'filters_2': 64,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.697536058291782,
#    'dropout_ratio_2': 0.07799718279587592,
#    'optimizer': 'Adam',
#    'learning_rate': 0.009288248766483723,
#    'batch_size': 64,
#    'epochs': 48,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.874},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.6639853743768876,
#    'dropout_ratio_2': 0.5529367046766808,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00010880234861349244,
#    'batch_size': 32,
#    'epochs': 36,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8738},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 16,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 16,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.3632198972113065,
#    'dropout_ratio_2': 0.4111534750213582,
#    'optimizer': 'Nadam',
#    'batch_size': 32,
#    'epochs': 65,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8736},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.16978228769742715,
#    'dropout_ratio_2': 0.039908321767157875,
#    'optimizer': 'Adam',
#    'batch_size': 512,
#    'epochs': 12,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87352},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 5,
#    'neurons': 64,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.3825898960949356,
#    'dropout_ratio_2': 0.2945126654170674,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87348},
#  {'hyperparameters': {'batch_size': 32,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 5,
#    'kernel_size_2': 3,
#    'neurons': 128,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.38904418198694496,
#    'dropout_ratio_2': 0.21683056475766257,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.010346983070108976,
#    'epochs': 46,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87348},
#  {'hyperparameters': {'batch_size': 32,
#    'filters_1': 16,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'neurons': 256,
#    'embedding_dim': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.472733287349412,
#    'dropout_ratio_2': 0.7854599198148282,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00018236961107196984,
#    'epochs': 91,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87316},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 32,
#    'filters_2': 8,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6741648187890016,
#    'dropout_ratio_2': 0.14455996821094202,
#    'optimizer': 'Adamax',
#    'batch_size': 16,
#    'epochs': 33,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87312},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 128,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 256,
#    'embedding_dim': 32,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00019262099478743646,
#    'batch_size': 16,
#    'epochs': 68,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87296},
#  {'hyperparameters': {'filters_1': 16,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 256,
#    'embedding_dim': 8,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.2064080483116378,
#    'dropout_ratio_2': 0.4163467014979415,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00010467668867689615,
#    'batch_size': 32,
#    'epochs': 96,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87268},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 32,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.3350366501637169,
#    'dropout_ratio_2': 0.8094288325479434,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0005356799746182838,
#    'batch_size': 512,
#    'epochs': 90,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87248},
#  {'hyperparameters': {'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 16,
#    'filters_2': 256,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 16,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00654140008168817,
#    'batch_size': 256,
#    'epochs': 67,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87244},
#  {'hyperparameters': {'filters_1': 256,
#    'filters_2': 8,
#    'kernel_size_1': 3,
#    'kernel_size_2': 5,
#    'neurons': 16,
#    'embedding_dim': 128,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.894421560490515,
#    'dropout_ratio_2': 0.6468235455889666,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0002654348734204136,
#    'batch_size': 128,
#    'epochs': 77,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87236},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'embedding_dim': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.54515943520597,
#    'dropout_ratio_2': 0.2107775733686596,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0004504644009070914,
#    'batch_size': 512,
#    'epochs': 13,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87232},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters_1': 8,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'embedding_dim': 32,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.574823574247375,
#    'dropout_ratio_2': 0.04353969446330842,
#    'learning_rate': 0.0032461474854351374,
#    'batch_size': 128,
#    'epochs': 65,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87192},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 64,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.5464688435776963,
#    'dropout_ratio_2': 0.6212656687805236,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0004646275275469142,
#    'batch_size': 64,
#    'epochs': 80,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8718},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 8,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 64,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.17911021800808002,
#    'dropout_ratio_2': 0.4697037645982799,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00022050263582999575,
#    'batch_size': 16,
#    'epochs': 18,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87168},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7206560428212545,
#    'dropout_ratio_2': 0.7901698163604322,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.005441852588775701,
#    'batch_size': 128,
#    'epochs': 8,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8716},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 32,
#    'filters_2': 256,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 64,
#    'embedding_dim': 128,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00033569147011152447,
#    'batch_size': 64,
#    'epochs': 23,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8716},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 32,
#    'filters_2': 256,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 8,
#    'embedding_dim': 16,
#    'dropout_ratio_1': 0.43486429728835313,
#    'dropout_ratio_2': 0.47292380466250733,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.036674365595822246,
#    'batch_size': 32,
#    'epochs': 93,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87144},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 8,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 32,
#    'embedding_dim': 256,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.3015545699621408,
#    'dropout_ratio_2': 0.1590523551633068,
#    'optimizer': 'Adam',
#    'batch_size': 16,
#    'epochs': 15,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87136},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 256,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 16,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00033173280890536923,
#    'batch_size': 128,
#    'epochs': 100,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.87128},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 8,
#    'filters_2': 8,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 64,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.6710591235264012,
#    'dropout_ratio_2': 0.7065695876407458,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87116},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 8,
#    'filters_2': 8,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.4336248367371905,
#    'dropout_ratio_2': 0.08816050557821362,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87116},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 16,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 64,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0002744020411773344,
#    'batch_size': 16,
#    'epochs': 90,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87092},
#  {'hyperparameters': {'filters_1': 32,
#    'filters_2': 8,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 128,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.4890674472051734,
#    'dropout_ratio_2': 0.417807932756118,
#    'optimizer': 'Adam',
#    'learning_rate': 0.001696287337631704,
#    'batch_size': 512,
#    'epochs': 5,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87068},
#  {'hyperparameters': {'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'filters_1': 128,
#    'filters_2': 32,
#    'neurons': 64,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.03186868985176396,
#    'dropout_ratio_2': 0.32581816735096203,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00048300480186825993,
#    'batch_size': 256,
#    'epochs': 90,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5,
#    'dropout_ratio_2': 0.5,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 256,
#    'embedding_dim': 128,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00041234211681394285,
#    'batch_size': 32,
#    'epochs': 16,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'filters_1': 256,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 32,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.030686216989731573,
#    'dropout_ratio_2': 0.2941359931705424,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00037963012849939303,
#    'batch_size': 32,
#    'epochs': 14,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87028},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 128,
#    'filters_2': 32,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 256,
#    'dropout_ratio_1': 0.024005327731561676,
#    'dropout_ratio_2': 0.019155150338440285,
#    'optimizer': 'Adam',
#    'learning_rate': 0.000255310916222418,
#    'batch_size': 256,
#    'epochs': 26,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86996},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 32,
#    'filters_2': 16,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'embedding_dim': 256,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.47658198684683084,
#    'dropout_ratio_2': 0.759834146822617,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86992},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters_1': 256,
#    'filters_2': 32,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.8874794480865003,
#    'dropout_ratio_2': 0.004882279521514244,
#    'learning_rate': 0.0007844603301288496,
#    'batch_size': 32,
#    'epochs': 54,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86984},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'embedding_dim': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.35756061039227655,
#    'dropout_ratio_2': 0.6793434716460061,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00021402009658710264,
#    'batch_size': 64,
#    'epochs': 25,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86968},
#  {'hyperparameters': {'filters_1': 8,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.07107600594797542,
#    'dropout_ratio_2': 0.2411486301624586,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00013835809384114695,
#    'batch_size': 32,
#    'epochs': 76,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86964},
#  {'hyperparameters': {'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'filters_1': 64,
#    'filters_2': 64,
#    'neurons': 128,
#    'embedding_dim': 256,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6420038949856827,
#    'dropout_ratio_2': 0.8426606847362218,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0005505493269864988,
#    'batch_size': 16,
#    'epochs': 51,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8696},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 256,
#    'filters_2': 16,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'neurons': 32,
#    'embedding_dim': 256,
#    'dropout_ratio_1': 0.2054210977484235,
#    'dropout_ratio_2': 0.5645034739689223,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00026033361063944414,
#    'batch_size': 512,
#    'epochs': 36,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.86956},
#  {'hyperparameters': {'filters_1': 8,
#    'filters_2': 8,
#    'kernel_size_1': 7,
#    'kernel_size_2': 9,
#    'neurons': 32,
#    'embedding_dim': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7324336943788976,
#    'dropout_ratio_2': 0.7897530885824694,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0013984253309380088,
#    'batch_size': 16,
#    'epochs': 78,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86956},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 128,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.32410998294017385,
#    'dropout_ratio_2': 0.16173755043477697,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0029583120450850996,
#    'batch_size': 128,
#    'epochs': 79,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'filters_1': 8,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'embedding_dim': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.14835416400088067,
#    'dropout_ratio_2': 0.7032121964613268,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.003104733036044276,
#    'batch_size': 128,
#    'epochs': 49,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86908},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 32,
#    'filters_2': 32,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 32,
#    'dropout_ratio_1': 0.35662586757887177,
#    'dropout_ratio_2': 0.37387980285828776,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0008824517593435076,
#    'batch_size': 256,
#    'epochs': 52,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86876},
#  {'hyperparameters': {'filters_1': 32,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7060292174139478,
#    'dropout_ratio_2': 0.06689329028560763,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.08433502303968855,
#    'batch_size': 128,
#    'epochs': 67,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8684},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 32,
#    'embedding_dim': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.6711762071760196,
#    'dropout_ratio_2': 0.34524037715342504,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86828},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.19900629528576522,
#    'dropout_ratio_2': 0.7210166654677838,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.010196925144589485,
#    'batch_size': 16,
#    'epochs': 56,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86808},
#  {'hyperparameters': {'batch_size': 32,
#    'filters_1': 16,
#    'filters_2': 256,
#    'kernel_size_1': 3,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'embedding_dim': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.24087350724054304,
#    'dropout_ratio_2': 0.6691569143822135,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0014567430098165058,
#    'epochs': 72,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86772},
#  {'hyperparameters': {'filters_1': 64,
#    'filters_2': 8,
#    'kernel_size_1': 7,
#    'kernel_size_2': 9,
#    'neurons': 64,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.18316891789952164,
#    'dropout_ratio_2': 0.48421089119710653,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0884834788067305,
#    'batch_size': 16,
#    'epochs': 95,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86752},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 5,
#    'neurons': 128,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.22535624421055753,
#    'dropout_ratio_2': 0.1784251863302007,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86748},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'embedding_dim': 8,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.6970475419012143,
#    'dropout_ratio_2': 0.06503722722037453,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0003208852057756667,
#    'batch_size': 128,
#    'epochs': 68,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.8674},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'filters_1': 16,
#    'filters_2': 256,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'neurons': 16,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.6239772128035652,
#    'dropout_ratio_2': 0.41377606097237274,
#    'learning_rate': 0.0008767732178954843,
#    'batch_size': 64,
#    'epochs': 5,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86728},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 32,
#    'filters_2': 16,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'neurons': 16,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.0919820863182772,
#    'dropout_ratio_2': 0.3072334022332126,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86708},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.7583316679702985,
#    'dropout_ratio_2': 0.0059314347771625585,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0003040796150275393,
#    'batch_size': 32,
#    'epochs': 92,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.867},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 16,
#    'filters_2': 16,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'embedding_dim': 32,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5838292750762207,
#    'dropout_ratio_2': 0.6542294291043063,
#    'optimizer': 'Nadam',
#    'batch_size': 512,
#    'epochs': 80,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86684},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 32,
#    'filters_2': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'embedding_dim': 8,
#    'dropout_ratio_1': 0.6235392490315563,
#    'dropout_ratio_2': 0.09140271227428064,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0006836054604862777,
#    'batch_size': 256,
#    'epochs': 24,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86672},
#  {'hyperparameters': {'batch_size': 32,
#    'filters_1': 32,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 5,
#    'neurons': 128,
#    'embedding_dim': 16,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.5231418019284962,
#    'dropout_ratio_2': 0.4536075842462671,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.003230112045767848,
#    'epochs': 95,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86636},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 64,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.020215873193662515,
#    'dropout_ratio_2': 0.29578734559359304,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86632},
#  {'hyperparameters': {'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'filters_1': 32,
#    'filters_2': 64,
#    'neurons': 256,
#    'embedding_dim': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.565082950369062,
#    'dropout_ratio_2': 0.573589697125788,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00041234211681394285,
#    'batch_size': 32,
#    'epochs': 16,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86624},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.31726668664432656,
#    'dropout_ratio_2': 0.5645833801264301,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00033005399796045344,
#    'batch_size': 64,
#    'epochs': 12,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.8662},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 64,
#    'filters_2': 16,
#    'kernel_size_1': 7,
#    'kernel_size_2': 5,
#    'neurons': 32,
#    'embedding_dim': 16,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.5181704375689264,
#    'dropout_ratio_2': 0.5445860541895717,
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 88,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.8662},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 64,
#    'embedding_dim': 64,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5771938776115955,
#    'dropout_ratio_2': 0.2405770735514348,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8662},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 5,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.15470056832430482,
#    'dropout_ratio_2': 0.5184473897958706,
#    'optimizer': 'RMSprop',
#    'batch_size': 16,
#    'epochs': 14,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86612},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.027994340514017425,
#    'dropout_ratio_2': 0.26636870510159544,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00010355383896257616,
#    'batch_size': 64,
#    'epochs': 6,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86612},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'embedding_dim': 256,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.3168733692254397,
#    'dropout_ratio_2': 0.31692380684053506,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86596},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 8,
#    'filters_2': 16,
#    'kernel_size_1': 7,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'embedding_dim': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.4615325827954967,
#    'dropout_ratio_2': 0.34909636991597087,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86592},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 64,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.532921708543007,
#    'dropout_ratio_2': 0.01682031437253988,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86584},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 64,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.07866132037778494,
#    'dropout_ratio_2': 0.7160202634911359,
#    'optimizer': 'Adam',
#    'learning_rate': 0.0012290330457972727,
#    'batch_size': 32,
#    'epochs': 20,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86556},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 16,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'embedding_dim': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.8523194075730738,
#    'dropout_ratio_2': 0.12913907872583655,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00018484614174170346,
#    'batch_size': 64,
#    'epochs': 71,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.86552},
#  {'hyperparameters': {'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'filters_1': 32,
#    'filters_2': 64,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 64,
#    'embedding_dim': 64,
#    'dropout_ratio_1': 0.41511289992833944,
#    'dropout_ratio_2': 0.6637540903560305,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0014428742641358827,
#    'batch_size': 16,
#    'epochs': 69,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.86552},
#  {'hyperparameters': {'filters_1': 128,
#    'filters_2': 128,
#    'neurons': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 7,
#    'embedding_dim': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7378535048410387,
#    'dropout_ratio_2': 0.33368894831312024,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.01334965104356856,
#    'batch_size': 32,
#    'epochs': 51,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8654},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'filters_1': 8,
#    'filters_2': 32,
#    'kernel_size_1': 3,
#    'kernel_size_2': 5,
#    'neurons': 128,
#    'embedding_dim': 8,
#    'activation_1': 'relu',
# ...
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 8,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 8,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.011803711045635257,
#    'dropout_ratio_2': 0.6004670026287944,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0009211820999053567,
#    'batch_size': 16,
#    'epochs': 76,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 16,
#    'filters_2': 8,
#    'kernel_size_1': 3,
#    'kernel_size_2': 5,
#    'neurons': 16,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.06468720231045261,
#    'dropout_ratio_2': 0.4195910865338718,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0007982790969186325,
#    'batch_size': 256,
#    'epochs': 79,
#    'pool_type': 'globalavg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 256,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.4255874535933392,
#    'dropout_ratio_2': 0.20855558324279605,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0010051014616990937,
#    'batch_size': 64,
#    'epochs': 50,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 256,
#    'filters_2': 8,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6763845400220262,
#    'dropout_ratio_2': 0.12454846965811349,
#    'optimizer': 'SGD',
#    'learning_rate': 0.05185362525776314,
#    'batch_size': 128,
#    'epochs': 33,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 8,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 8,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.6298274920174134,
#    'dropout_ratio_2': 0.06566914560767897,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.08956665491475073,
#    'batch_size': 512,
#    'epochs': 54,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 8,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.39800122493808077,
#    'dropout_ratio_2': 0.034297664682942854,
#    'optimizer': 'Adam',
#    'learning_rate': 0.014124686042775399,
#    'batch_size': 16,
#    'epochs': 6,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 256,
#    'filters_2': 16,
#    'kernel_size_1': 5,
#    'kernel_size_2': 3,
#    'neurons': 32,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.612031224075106,
#    'dropout_ratio_2': 0.7144332629348966,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0074473071722656785,
#    'batch_size': 256,
#    'epochs': 48,
#    'pool_type': 'globalavg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 32,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.8500481204910114,
#    'dropout_ratio_2': 0.8573909702681015,
#    'optimizer': 'SGD',
#    'learning_rate': 0.0005541397900778611,
#    'batch_size': 16,
#    'epochs': 94,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 256,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.17064992804266377,
#    'dropout_ratio_2': 0.6196755728244475,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00017140451055636712,
#    'batch_size': 32,
#    'epochs': 94,
#    'pool_type': 'globalavg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 16,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 9,
#    'neurons': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.40140519086429,
#    'dropout_ratio_2': 0.18310251865966592,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.005457830126872589,
#    'batch_size': 256,
#    'epochs': 86,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 128,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.535536540357108,
#    'dropout_ratio_2': 0.2103920120635356,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0001728075602020997,
#    'batch_size': 64,
#    'epochs': 36,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 3,
#    'kernel_size_2': 3,
#    'neurons': 8,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.5568136294132742,
#    'dropout_ratio_2': 0.6582419445262502,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0045234062533584555,
#    'batch_size': 128,
#    'epochs': 40,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 32,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 3,
#    'neurons': 128,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.08589666372156549,
#    'dropout_ratio_2': 0.047958535082312695,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.019648468235539163,
#    'batch_size': 256,
#    'epochs': 95,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.826328120840305,
#    'dropout_ratio_2': 0.8101427730251834,
#    'optimizer': 'SGD',
#    'learning_rate': 0.007371287947368475,
#    'batch_size': 32,
#    'epochs': 28,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 32,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 64,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6522585088100051,
#    'dropout_ratio_2': 0.8736838494452691,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.00020874293988881878,
#    'batch_size': 64,
#    'epochs': 47,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.7412511073070822,
#    'dropout_ratio_2': 0.8993059172623973,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.035201924248554894,
#    'batch_size': 32,
#    'epochs': 41,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 5,
#    'neurons': 32,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.7378582419171624,
#    'dropout_ratio_2': 0.5594505334483578,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.024276753739718358,
#    'batch_size': 64,
#    'epochs': 3,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 5,
#    'neurons': 256,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.2707351701996023,
#    'dropout_ratio_2': 0.8724281448648187,
#    'optimizer': 'SGD',
#    'learning_rate': 0.014675519254499649,
#    'batch_size': 64,
#    'epochs': 4,
#    'pool_type': 'globalmax',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 32,
#    'filters_2': 256,
#    'kernel_size_1': 5,
#    'kernel_size_2': 7,
#    'neurons': 128,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.7639533256807208,
#    'dropout_ratio_2': 0.3745854885721446,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0020780367938768155,
#    'batch_size': 32,
#    'epochs': 8,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 32,
#    'filters_2': 8,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 256,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.6891896837751935,
#    'dropout_ratio_2': 0.6930049765261006,
#    'optimizer': 'Ftrl',
#    'learning_rate': 0.004020236007046608,
#    'batch_size': 128,
#    'epochs': 83,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 8,
#    'filters_2': 128,
#    'kernel_size_1': 9,
#    'kernel_size_2': 3,
#    'neurons': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.05754425203265463,
#    'dropout_ratio_2': 0.46472615380639926,
#    'optimizer': 'SGD',
#    'learning_rate': 0.033722819423175746,
#    'batch_size': 64,
#    'epochs': 81,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 256,
#    'filters_2': 128,
#    'kernel_size_1': 3,
#    'kernel_size_2': 5,
#    'neurons': 32,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.03797210181458093,
#    'dropout_ratio_2': 0.8024776403560194,
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0005218136255061414,
#    'batch_size': 128,
#    'epochs': 78,
#    'pool_type': 'globalavg',
#    'loss_function': 'poisson'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 64,
#    'filters_2': 64,
#    'kernel_size_1': 9,
#    'kernel_size_2': 9,
#    'neurons': 8,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5785125957798096,
#    'dropout_ratio_2': 0.5236992840364382,
#    'optimizer': 'Adam',
#    'learning_rate': 0.006017119248037566,
#    'batch_size': 64,
#    'epochs': 47,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 128,
#    'filters_2': 64,
#    'kernel_size_1': 7,
#    'kernel_size_2': 3,
#    'neurons': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.18382549087792374,
#    'dropout_ratio_2': 0.3714776606705981,
#    'optimizer': 'Adam',
#    'learning_rate': 0.06515573396374617,
#    'batch_size': 16,
#    'epochs': 64,
#    'pool_type': 'globalavg',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'embedding_dim': 128,
#    'filters_1': 8,
#    'filters_2': 64,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 128,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.7148591211505142,
#    'dropout_ratio_2': 0.6310658295535401,
#    'optimizer': 'Adam',
#    'learning_rate': 0.00054450236872239,
#    'batch_size': 128,
#    'epochs': 67,
#    'pool_type': 'globalmax',
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 128,
#    'kernel_size_1': 5,
#    'kernel_size_2': 5,
#    'neurons': 256,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.5702304910643927,
#    'dropout_ratio_2': 0.4686853024433816,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 16,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 16,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.5130692901964793,
#    'dropout_ratio_2': 0.302168389731431,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 32,
#    'kernel_size_1': 9,
#    'kernel_size_2': 5,
#    'neurons': 8,
#    'embedding_dim': 8,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.6503845686048589,
#    'dropout_ratio_2': 0.6562632933292395,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 32,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 8,
#    'embedding_dim': 256,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'activation_3': 'sigmoid',
#    'dropout_ratio_1': 0.5922398451983102,
#    'dropout_ratio_2': 0.8950922374619122,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 16,
#    'filters_2': 32,
#    'kernel_size_1': 3,
#    'kernel_size_2': 9,
#    'neurons': 16,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'activation_3': 'tanh',
#    'dropout_ratio_1': 0.311292038159773,
#    'dropout_ratio_2': 0.7158630379241907,
#    'pool_type': 'globalavg',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 3,
#    'filters_1': 256,
#    'filters_2': 256,
#    'kernel_size_1': 7,
#    'kernel_size_2': 7,
#    'neurons': 64,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'activation_3': 'relu',
#    'dropout_ratio_1': 0.2713275058571948,
#    'dropout_ratio_2': 0.3238574060956504,
#    'pool_type': 'globalmax',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.5},
#  ...]

# %% [markdown]
# ### LSTM

# %%
lstm_recorder = dict()

# %%
parent_dir = "TOSEM_data/lstm_data/lstm_data_server/all100_model_performance_properties/"
for folder in os.listdir(parent_dir):
    if folder == '.DS_Store':
        continue
    for record in os.listdir(os.path.join(parent_dir, folder)):
        if record.endswith("metrics"):
            target = os.path.join(parent_dir, folder, record)
            with open(target, "r") as ifile:
                temp = ifile.read()
                temp = json.loads(temp)
                lstm_recorder[folder + "_" + record] = temp

# %%
simlified_lstm_result_list = list()
for key in lstm_recorder:
    temp = dict()
    temp["hyperparameters"] = lstm_recorder[key]["hyperparameters"]
    temp["accuracy"] = np.median(lstm_recorder[key]["original_model"]["accuracy"])
    simlified_lstm_result_list.append(temp)

# %%
sorted(simlified_lstm_result_list, key=lambda x:x["accuracy"], reverse=True)
# Out:
# [{'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5876846893466073,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'batch_size': 16,
#    'epochs': 73,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.89112},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5876846893466073,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'batch_size': 16,
#    'epochs': 73,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.89112},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.37321540014297205,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0021501001617229517,
#    'batch_size': 16,
#    'epochs': 42,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88896},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.37321540014297205,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0021501001617229517,
#    'batch_size': 16,
#    'epochs': 42,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88896},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 16,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4983060534816024,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.006996259417486661,
#    'epochs': 100,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88584},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 16,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4983060534816024,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.006996259417486661,
#    'epochs': 100,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88584},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.8780945294885381,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0029219721287905426,
#    'epochs': 88,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8844},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.8780945294885381,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0029219721287905426,
#    'epochs': 88,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8844},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.45479510818723684,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00013057357271931667,
#    'batch_size': 64,
#    'epochs': 95,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.883},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.45479510818723684,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00013057357271931667,
#    'batch_size': 64,
#    'epochs': 95,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.883},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4620737432363429,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0001810511799640254,
#    'epochs': 79,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88252},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4620737432363429,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0001810511799640254,
#    'epochs': 79,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88252},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.2439592775506386,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.003934288541412169,
#    'batch_size': 16,
#    'epochs': 11,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88132},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.2439592775506386,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.003934288541412169,
#    'batch_size': 16,
#    'epochs': 11,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88132},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8191421534944631,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.014348090036477402,
#    'batch_size': 16,
#    'epochs': 32,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8191421534944631,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.014348090036477402,
#    'batch_size': 16,
#    'epochs': 32,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.88},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 256,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0035579953677778798,
#    'batch_size': 64,
#    'epochs': 88,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87908},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 256,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0035579953677778798,
#    'batch_size': 64,
#    'epochs': 88,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87908},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 256,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0035579953677778798,
#    'batch_size': 64,
#    'epochs': 88,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87908},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8510570590623578,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 64,
#    'epochs': 43,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87832},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8510570590623578,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 64,
#    'epochs': 43,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87832},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 64,
#    'units_2': 256,
#    'dropout_ratio': 0.2556087520889408,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.016504450241991125,
#    'batch_size': 64,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87692},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 64,
#    'units_2': 256,
#    'dropout_ratio': 0.2556087520889408,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.016504450241991125,
#    'batch_size': 64,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87692},
#  {'hyperparameters': {'epochs': 2,
#    'units_1': 16,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.20724615834210944,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adam',
#    'learning_rate': 0.010555735050978813,
#    'batch_size': 16,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87652},
#  {'hyperparameters': {'epochs': 2,
#    'units_1': 16,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.20724615834210944,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adam',
#    'learning_rate': 0.010555735050978813,
#    'batch_size': 16,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87652},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.6717899154568345,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87616},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.6717899154568345,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87616},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.6219793791776344,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.015062788883686472,
#    'batch_size': 128,
#    'epochs': 98,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87536},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.6219793791776344,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.015062788883686472,
#    'batch_size': 128,
#    'epochs': 98,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87536},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.566244620251593,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.000824966994861931,
#    'epochs': 91,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87508},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.566244620251593,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.000824966994861931,
#    'epochs': 91,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87508},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5230369192541082,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.013553491857069862,
#    'batch_size': 32,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.875},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5824743939429944,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.875},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5230369192541082,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.013553491857069862,
#    'batch_size': 32,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.875},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5824743939429944,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.875},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0004939190062035757,
#    'batch_size': 32,
#    'epochs': 38,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87468},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0004939190062035757,
#    'batch_size': 32,
#    'epochs': 38,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87468},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0004939190062035757,
#    'batch_size': 32,
#    'epochs': 38,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87468},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.5549119128291775,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8746},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.5549119128291775,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8746},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.692075270658536,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0019586936025796976,
#    'batch_size': 64,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87436},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.692075270658536,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0019586936025796976,
#    'batch_size': 64,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87436},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0026076926140610134,
#    'batch_size': 64,
#    'epochs': 5,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87364},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0026076926140610134,
#    'batch_size': 64,
#    'epochs': 5,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87364},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6668344834227997,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 100,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87352},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6668344834227997,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 100,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87352},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 256,
#    'units_2': 64,
#    'dropout_ratio': 0.8235953634140901,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00041421618270650527,
#    'batch_size': 128,
#    'epochs': 39,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87304},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 256,
#    'units_2': 64,
#    'dropout_ratio': 0.8235953634140901,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00041421618270650527,
#    'batch_size': 128,
#    'epochs': 39,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87304},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8385152898732577,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0032601559742861798,
#    'batch_size': 256,
#    'epochs': 31,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.873},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8385152898732577,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.0032601559742861798,
#    'batch_size': 256,
#    'epochs': 31,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.873},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.488722100575423,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 64,
#    'epochs': 85,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87288},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.488722100575423,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'batch_size': 64,
#    'epochs': 85,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87288},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.5572111936638264,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010960355985850537,
#    'batch_size': 64,
#    'epochs': 80,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87236},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.5572111936638264,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010960355985850537,
#    'batch_size': 64,
#    'epochs': 80,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87236},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00011456149313826463,
#    'batch_size': 64,
#    'epochs': 62,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87208},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00011456149313826463,
#    'batch_size': 64,
#    'epochs': 62,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87208},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8912858680655219,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.006493679667957453,
#    'batch_size': 64,
#    'epochs': 12,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87192},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.8912858680655219,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.006493679667957453,
#    'batch_size': 64,
#    'epochs': 12,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87192},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8362439025669145,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0007657733493602305,
#    'epochs': 26,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8718},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8362439025669145,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0007657733493602305,
#    'epochs': 26,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8718},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 128,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.7840805203177061,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00018220047585649685,
#    'epochs': 36,
#    'loss_function': 'poisson'},
#   'accuracy': 0.87176},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 128,
#    'units_2': 16,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.7840805203177061,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00018220047585649685,
#    'epochs': 36,
#    'loss_function': 'poisson'},
#   'accuracy': 0.87176},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.26190315343129744,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87168},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.26190315343129744,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87168},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 128,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.06733845399391296,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0007657733493602305,
#    'batch_size': 64,
#    'epochs': 55,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8716},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 128,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.06733845399391296,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0007657733493602305,
#    'batch_size': 64,
#    'epochs': 55,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8716},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00031999181557582117,
#    'batch_size': 16,
#    'epochs': 46,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87148},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 32,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00031999181557582117,
#    'batch_size': 16,
#    'epochs': 46,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87148},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 32,
#    'units_2': 64,
#    'dropout_ratio': 0.3448567097532936,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0022287787644442304,
#    'batch_size': 64,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8714},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 32,
#    'units_2': 64,
#    'dropout_ratio': 0.3448567097532936,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0022287787644442304,
#    'batch_size': 64,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8714},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.6261533183003553,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87116},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.6261533183003553,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87116},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.7935873206941069,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.02035165694576651,
#    'batch_size': 16,
#    'epochs': 53,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87112},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.7935873206941069,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.02035165694576651,
#    'batch_size': 16,
#    'epochs': 53,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87112},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.04721556777691984,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.01074781308777743,
#    'batch_size': 256,
#    'epochs': 94,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.871},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.04721556777691984,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.01074781308777743,
#    'batch_size': 256,
#    'epochs': 94,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.871},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 256,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0013705602099255735,
#    'batch_size': 256,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87096},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 256,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0013705602099255735,
#    'batch_size': 256,
#    'epochs': 14,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87096},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.02934317782605337,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'batch_size': 16,
#    'epochs': 56,
#    'loss_function': 'poisson'},
#   'accuracy': 0.8706},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.02934317782605337,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'batch_size': 16,
#    'epochs': 56,
#    'loss_function': 'poisson'},
#   'accuracy': 0.8706},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.2705119897579346,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.6255127247479205,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00023687340664200153,
#    'batch_size': 256,
#    'epochs': 15,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.2705119897579346,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.6255127247479205,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00023687340664200153,
#    'batch_size': 256,
#    'epochs': 15,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87052},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.07382387036469414,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00015554944612839545,
#    'batch_size': 64,
#    'epochs': 18,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8704},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.7062888690883556,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00256237276768461,
#    'batch_size': 64,
#    'epochs': 58,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8704},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.07382387036469414,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00015554944612839545,
#    'batch_size': 64,
#    'epochs': 18,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8704},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.7062888690883556,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.00256237276768461,
#    'batch_size': 64,
#    'epochs': 58,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8704},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.24087350724054304,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0014567430098165058,
#    'epochs': 72,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87012},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5713121911382781,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.011285671167104465,
#    'batch_size': 64,
#    'epochs': 6,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87012},
#  {'hyperparameters': {'batch_size': 32,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.24087350724054304,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0014567430098165058,
#    'epochs': 72,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87012},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5713121911382781,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.011285671167104465,
#    'batch_size': 64,
#    'epochs': 6,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.87012},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.38151545193519876,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00037321703563729353,
#    'batch_size': 64,
#    'epochs': 53,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86992},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.38151545193519876,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00037321703563729353,
#    'batch_size': 64,
#    'epochs': 53,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86992},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00043417906462748954,
#    'batch_size': 128,
#    'epochs': 23,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86968},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00043417906462748954,
#    'batch_size': 128,
#    'epochs': 23,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86968},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.00043417906462748954,
#    'batch_size': 128,
#    'epochs': 23,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86968},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.4036147583660198,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'learning_rate': 0.0025712001205139743,
#    'batch_size': 16,
#    'epochs': 64,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86956},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.4036147583660198,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'learning_rate': 0.0025712001205139743,
#    'batch_size': 16,
#    'epochs': 64,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86956},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.06270835444147252,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006491302469881165,
#    'batch_size': 128,
#    'epochs': 57,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86952},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.06270835444147252,
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0006491302469881165,
#    'batch_size': 128,
#    'epochs': 57,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86952},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0026619975274872498,
#    'batch_size': 16,
#    'epochs': 69,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.13749562894039524,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.003334642407042207,
#    'batch_size': 128,
#    'epochs': 71,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0026619975274872498,
#    'batch_size': 16,
#    'epochs': 69,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.13749562894039524,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.003334642407042207,
#    'batch_size': 128,
#    'epochs': 71,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0026619975274872498,
#    'batch_size': 16,
#    'epochs': 69,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86944},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.2874157793683372,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8694},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.2874157793683372,
#    'activation_1': 'sigmoid',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8694},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.4697037645982799,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00010284614264438624,
#    'batch_size': 32,
#    'epochs': 67,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8688},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.4697037645982799,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.00010284614264438624,
#    'batch_size': 32,
#    'epochs': 67,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8688},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 128,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.001845147889954415,
#    'batch_size': 16,
#    'epochs': 74,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86872},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 128,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.001845147889954415,
#    'batch_size': 16,
#    'epochs': 74,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86872},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 64,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.043249582032349985,
#    'batch_size': 512,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86852},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 64,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.043249582032349985,
#    'batch_size': 512,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86852},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 64,
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.043249582032349985,
#    'batch_size': 512,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86852},
#  {'hyperparameters': {'epochs': 2,
#    'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5194182905094659,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0009587577437887735,
#    'batch_size': 32,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86848},
#  {'hyperparameters': {'epochs': 2,
#    'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.5194182905094659,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0009587577437887735,
#    'batch_size': 32,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86848},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.19435605766453615,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.008514542675036612,
#    'batch_size': 256,
#    'epochs': 91,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86836},
#  {'hyperparameters': {'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.19435605766453615,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.008514542675036612,
#    'batch_size': 256,
#    'epochs': 91,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86836},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.21571038422571465,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'batch_size': 32,
#    'epochs': 28,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86828},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.21571038422571465,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'batch_size': 32,
#    'epochs': 28,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86828},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6048615554123385,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'learning_rate': 0.00013509400284333068,
#    'batch_size': 64,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86812},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6048615554123385,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'learning_rate': 0.00013509400284333068,
#    'batch_size': 64,
#    'epochs': 75,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86812},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.542687842327576,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adam',
#    'batch_size': 16,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86796},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 64,
#    'units_2': 32,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.542687842327576,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adam',
#    'batch_size': 16,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86796},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 256,
#    'units_2': 128,
#    'dropout_ratio': 0.5758152321684985,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0011059738723526579,
#    'batch_size': 64,
#    'epochs': 60,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86788},
#  {'hyperparameters': {'embedding_dim': 128,
#    'units_1': 256,
#    'units_2': 128,
#    'dropout_ratio': 0.5758152321684985,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0011059738723526579,
#    'batch_size': 64,
#    'epochs': 60,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86788},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6469228847863687,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'batch_size': 128,
#    'epochs': 16,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86784},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.6469228847863687,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'batch_size': 128,
#    'epochs': 16,
#    'loss_function': 'poisson'},
#   'accuracy': 0.86784},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.3818358622757749,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86772},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.3818358622757749,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86772},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010487749746860195,
#    'batch_size': 64,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86768},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010487749746860195,
#    'batch_size': 64,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86768},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'optimizer': 'Adamax',
#    'learning_rate': 0.0010487749746860195,
#    'batch_size': 64,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86768},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.4620751638784432,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 65,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86744},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.4620751638784432,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'Adamax',
#    'batch_size': 32,
#    'epochs': 65,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86744},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.535536540357108,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86724},
#  {'hyperparameters': {'optimizer': 'Adam',
#    'learning_rate': 0.001,
#    'batch_size': 32,
#    'epochs': 2,
#    'units_1': 16,
#    'units_2': 32,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.535536540357108,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.86724},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.019474618421346714,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adam',
#    'batch_size': 64,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.8672},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.019474618421346714,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adam',
#    'batch_size': 64,
#    'epochs': 8,
#    'loss_function': 'binary_crossentropy'},
# ...
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0008068735178418917,
#    'batch_size': 32,
#    'epochs': 73,
#    'loss_function': 'poisson'},
#   'accuracy': 0.53},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 16,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.16528009584442016,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0008068735178418917,
#    'batch_size': 32,
#    'epochs': 73,
#    'loss_function': 'poisson'},
#   'accuracy': 0.53},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.07107600594797542,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.06530528083397598,
#    'batch_size': 64,
#    'epochs': 13,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52976},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.07107600594797542,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.06530528083397598,
#    'batch_size': 64,
#    'epochs': 13,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52976},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.24399944433011717,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.000526170860604658,
#    'batch_size': 32,
#    'epochs': 39,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52892},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.24399944433011717,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.000526170860604658,
#    'batch_size': 32,
#    'epochs': 39,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52892},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'SGD',
#    'learning_rate': 0.004490847060886868,
#    'batch_size': 32,
#    'epochs': 63,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52872},
#  {'hyperparameters': {'dropout_ratio': 0.5,
#    'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'SGD',
#    'learning_rate': 0.004490847060886868,
#    'batch_size': 32,
#    'epochs': 63,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52872},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.062515287213331,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0006875247633283827,
#    'batch_size': 128,
#    'epochs': 53,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52776},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.062515287213331,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0006875247633283827,
#    'batch_size': 128,
#    'epochs': 53,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52776},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.16383499599727702,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adadelta',
#    'batch_size': 32,
#    'epochs': 64,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52772},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.16383499599727702,
#    'activation_1': 'tanh',
#    'activation_2': 'tanh',
#    'optimizer': 'Adadelta',
#    'batch_size': 32,
#    'epochs': 64,
#    'loss_function': 'poisson'},
#   'accuracy': 0.52772},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.6869044473129169,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'SGD',
#    'batch_size': 128,
#    'epochs': 45,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52716},
#  {'hyperparameters': {'learning_rate': 0.001,
#    'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.6869044473129169,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'SGD',
#    'batch_size': 128,
#    'epochs': 45,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.52716},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.8494487184135465,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.008670488190778996,
#    'batch_size': 64,
#    'epochs': 91,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.43453279806254463,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.010260144072139944,
#    'batch_size': 16,
#    'epochs': 66,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.035953826234434196,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.08638087527161876,
#    'batch_size': 512,
#    'epochs': 7,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.7552224191638812,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.005140988480491339,
#    'batch_size': 512,
#    'epochs': 49,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.44454054208030125,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.06319808421258696,
#    'batch_size': 32,
#    'epochs': 77,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.0002510224856525856,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.08283880554463637,
#    'batch_size': 512,
#    'epochs': 88,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.31519997788422727,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.00013768736261195804,
#    'batch_size': 32,
#    'epochs': 2,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.7638652504082223,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00013299687801867667,
#    'batch_size': 32,
#    'epochs': 3,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.26497351256397345,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0466347391112094,
#    'batch_size': 256,
#    'epochs': 58,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.4835558416675463,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.07738953414178386,
#    'batch_size': 512,
#    'epochs': 68,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8895744921003809,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.06830391613984356,
#    'batch_size': 128,
#    'epochs': 84,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.06713507114639694,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adam',
#    'learning_rate': 0.007393556867732781,
#    'batch_size': 512,
#    'epochs': 65,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4535327152673689,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0010475386009636152,
#    'batch_size': 128,
#    'epochs': 46,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.4711964759213594,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.012172793543242971,
#    'batch_size': 512,
#    'epochs': 13,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 256,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.03831782640915843,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0046674722992577425,
#    'batch_size': 512,
#    'epochs': 30,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 16,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.2795382027879265,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adam',
#    'learning_rate': 0.0086743182667461,
#    'batch_size': 512,
#    'epochs': 36,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 16,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.3162063541633892,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.03391704262019838,
#    'batch_size': 256,
#    'epochs': 73,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5899251665109095,
#    'activation_1': 'sigmoid',
#    'activation_2': 'tanh',
#    'optimizer': 'SGD',
#    'learning_rate': 0.002327249375814318,
#    'batch_size': 16,
#    'epochs': 48,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.6343408241477149,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.08003918383307998,
#    'batch_size': 32,
#    'epochs': 58,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 128,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.8191171591154855,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Adadelta',
#    'learning_rate': 0.0006856827308487193,
#    'batch_size': 128,
#    'epochs': 94,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 16,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.4537908857226558,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.0044952866004098965,
#    'batch_size': 16,
#    'epochs': 11,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 64,
#    'units_2': 64,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.4967561722272342,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.006039703545822296,
#    'batch_size': 16,
#    'epochs': 34,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 16,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.086836595843597,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.04824014039833979,
#    'batch_size': 256,
#    'epochs': 26,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 128,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.016379756184439154,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.03080699394231419,
#    'batch_size': 128,
#    'epochs': 82,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.5153236418542045,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.0013527656372130021,
#    'batch_size': 32,
#    'epochs': 18,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.8494487184135465,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Adam',
#    'learning_rate': 0.008670488190778996,
#    'batch_size': 64,
#    'epochs': 91,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 256,
#    'dropout_ratio': 0.43453279806254463,
#    'activation_1': 'tanh',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.010260144072139944,
#    'batch_size': 16,
#    'epochs': 66,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 128,
#    'units_2': 32,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.035953826234434196,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'RMSprop',
#    'learning_rate': 0.08638087527161876,
#    'batch_size': 512,
#    'epochs': 7,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 16,
#    'units_2': 64,
#    'embedding_dim': 128,
#    'dropout_ratio': 0.7552224191638812,
#    'activation_1': 'relu',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.005140988480491339,
#    'batch_size': 512,
#    'epochs': 49,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 128,
#    'embedding_dim': 32,
#    'dropout_ratio': 0.44454054208030125,
#    'activation_1': 'relu',
#    'activation_2': 'relu',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.06319808421258696,
#    'batch_size': 32,
#    'epochs': 77,
#    'loss_function': 'kullback_leibler_divergence'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 256,
#    'units_2': 256,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.0002510224856525856,
#    'activation_1': 'relu',
#    'activation_2': 'tanh',
#    'optimizer': 'Nadam',
#    'learning_rate': 0.08283880554463637,
#    'batch_size': 512,
#    'epochs': 88,
#    'loss_function': 'poisson'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 64,
#    'embedding_dim': 16,
#    'dropout_ratio': 0.31519997788422727,
#    'activation_1': 'tanh',
#    'activation_2': 'sigmoid',
#    'optimizer': 'SGD',
#    'learning_rate': 0.00013768736261195804,
#    'batch_size': 32,
#    'epochs': 2,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  {'hyperparameters': {'units_1': 32,
#    'units_2': 256,
#    'embedding_dim': 64,
#    'dropout_ratio': 0.7638652504082223,
#    'activation_1': 'sigmoid',
#    'activation_2': 'relu',
#    'optimizer': 'Adagrad',
#    'learning_rate': 0.00013299687801867667,
#    'batch_size': 32,
#    'epochs': 3,
#    'loss_function': 'binary_crossentropy'},
#   'accuracy': 0.526},
#  ...]
